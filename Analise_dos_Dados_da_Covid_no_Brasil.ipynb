# %% [markdown]
# <a href="https://colab.research.google.com/github/PRJacovac/dio-desafio-python-e-pandas/blob/main/Analise_dos_Dados_da_Covid_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Importando Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2) Lendo os Arquivos

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/HIST_PAINEL_COVIDBR_2022_Parte2_26set2022.csv", sep=";")
display(df)
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0             Brasil    NaN       NaN     76       NaN             NaN
# 1             Brasil    NaN       NaN     76       NaN             NaN
# 2             Brasil    NaN       NaN     76       NaN             NaN
# 3             Brasil    NaN       NaN     76       NaN             NaN
# 4             Brasil    NaN       NaN     76       NaN             NaN
# ...              ...    ...       ...    ...       ...             ...
# 494467  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 494468  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 494469  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 494470  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 494471  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %% [markdown]
# 3) Visualizar as 5 primeiras linhas

# %%
df.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  casosNovos  \
# 0  2022-07-01         26       210147125.0        32434063       76045
# 1  2022-07-02         26       210147125.0        32471847       37784
# 2  2022-07-03         27       210147125.0        32490422       18575
# 3  2022-07-04         27       210147125.0        32535923       45501
# 4  2022-07-05         27       210147125.0        32610514       74591
#
#    obitosAcumulado  obitosNovos  Recuperadosnovos  emAcompanhamentoNovos  \
# ...

# %% [markdown]
# Visualização das 5 ultimas linhas

# %%
df.tail()
# Out:
#               regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 494467  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 494468  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 494469  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 494470  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 494471  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#          nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 494467  DISTRITO FEDERAL  2022-09-22         38         3015268.0
# 494468  DISTRITO FEDERAL  2022-09-23         38         3015268.0
# 494469  DISTRITO FEDERAL  2022-09-24         38         3015268.0
# 494470  DISTRITO FEDERAL  2022-09-25         39         3015268.0
# 494471  DISTRITO FEDERAL  2022-09-26         39         3015268.0
#
#         casosAcumulado  casosNovos  obitosAcumulado  obitosNovos  \
# 494467          838619          46            11829            0
# ...

# %% [markdown]
# Verificando o tamanho da base de dados

# %%
df.shape
# Out:
# (494472, 17)

# %% [markdown]
# Verificando valores nulos e tipos de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494472 entries, 0 to 494471
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   regiao                  494472 non-null  object
#  1   estado                  494384 non-null  object
#  2   municipio               490160 non-null  object
#  3   coduf                   494472 non-null  int64
#  4   codmun                  492008 non-null  float64
#  5   codRegiaoSaude          490160 non-null  float64
#  6   nomeRegiaoSaude         490160 non-null  object
#  7   data                    494472 non-null  object
#  8   semanaEpi               494472 non-null  int64
#  9   populacaoTCU2019        492624 non-null  float64
#  10  casosAcumulado          494472 non-null  int64
#  11  casosNovos              494472 non-null  int64
#  12  obitosAcumulado         494472 non-null  int64
#  13  obitosNovos             494472 non-null  int64
# ...

# %% [markdown]
# Verificando os tipos de dados

# %%
df.dtypes
# Out:
# regiao                     object
# estado                     object
# municipio                  object
# coduf                       int64
# codmun                    float64
# codRegiaoSaude            float64
# nomeRegiaoSaude            object
# data                       object
# semanaEpi                   int64
# populacaoTCU2019          float64
# casosAcumulado              int64
# casosNovos                  int64
# obitosAcumulado             int64
# obitosNovos                 int64
# Recuperadosnovos          float64
# emAcompanhamentoNovos     float64
# interior/metropolitana    float64
# dtype: object

# %% [markdown]
# Verificando a existência de dados nulos

# %%
df.isnull().sum()
# Out:
# regiao                         0
# estado                        88
# municipio                   4312
# coduf                          0
# codmun                      2464
# codRegiaoSaude              4312
# nomeRegiaoSaude             4312
# data                           0
# semanaEpi                      0
# populacaoTCU2019            1848
# casosAcumulado                 0
# casosNovos                     0
# obitosAcumulado                0
# obitosNovos                    0
# Recuperadosnovos          494385
# emAcompanhamentoNovos     494385
# interior/metropolitana      4312
# dtype: int64

# %% [markdown]
# Entendendo os valores nulos

# %%
df['municipio'].value_counts()
# Out:
# Bom Jesus               440
# São Domingos            440
# Bonito                  352
# Santa Helena            352
# Santa Terezinha         352
#                        ...
# Conceição do Jacuípe     88
# Conceição do Coité       88
# Conceição do Almeida     88
# Conceição da Feira       88
# Brasília                 88
# Name: municipio, Length: 5297, dtype: int64

# %% [markdown]
# Dados estatísticos da planilha

# %%
df.describe()
# Out:
#                coduf         codmun  codRegiaoSaude      semanaEpi  \
# count  494472.000000  492008.000000   490160.000000  494472.000000
# mean       32.360384  325258.014130    32403.123698      32.500000
# std         9.873306   98535.124336     9836.351340       3.646297
# min        11.000000  110000.000000    11001.000000      26.000000
# 25%        25.000000  251200.000000    25010.000000      29.000000
# 50%        31.000000  314610.000000    31059.000000      32.500000
# 75%        41.000000  411915.000000    41015.000000      36.000000
# max        76.000000  530010.000000    53001.000000      39.000000
#
#        populacaoTCU2019  casosAcumulado     casosNovos  obitosAcumulado  \
# count      4.926240e+05    4.944720e+05  494472.000000    494472.000000
# mean       1.126190e+05    1.812406e+04      13.834575       363.252912
# std        2.935317e+06    4.705770e+05     499.808203      9575.658759
# min        7.810000e+02    0.000000e+00  -30211.000000         0.000000
# ...

# %% [markdown]
# "Plotando" as informações de casos acumulados

# %%
df [df.estado.isna()].casosAcumulado.plot()

# %% [markdown]
# "Plotando" as informações de novos casos

# %%
df[df.estado.isna()].casosNovos.plot()

# %% [markdown]
# Buscando as informações de "obitos novos"

# %%
df.sort_values(by=['obitosNovos']).head(10)
# Out:
#          regiao estado   municipio  coduf    codmun  codRegiaoSaude  \
# 96068  Nordeste     CE      Sobral     23  231290.0         23011.0
# 96084  Nordeste     CE      Sobral     23  231290.0         23011.0
# 96173  Nordeste     CE  Solonópole     23  231300.0         23008.0
# 96157  Nordeste     CE  Solonópole     23  231300.0         23008.0
# 96508  Nordeste     CE        Tauá     23  231330.0         23014.0
# 96524  Nordeste     CE        Tauá     23  231330.0         23014.0
# 96597  Nordeste     CE   Tejuçuoca     23  231335.0         23002.0
# 96613  Nordeste     CE   Tejuçuoca     23  231335.0         23002.0
# 96700  Nordeste     CE     Tianguá     23  231340.0         23013.0
# 96684  Nordeste     CE     Tianguá     23  231340.0         23013.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 96068   11ª REGIAO SOBRAL  2022-08-30         35          208935.0
# 96084   11ª REGIAO SOBRAL  2022-09-15         37          208935.0
# ...

# %% [markdown]
# Verificando se há duplicidade de dados em determinada região

# %%
df[df.regiao == 'Sudeste'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Verificando quantidade de contaminados e recuperados por região

# %%
contaminados_x_recuperados = df[['regiao', 'casosAcumulado', 'Recuperadosnovos']].groupby('regiao').sum()
display(contaminados_x_recuperados)
# Out:
#               casosAcumulado  Recuperadosnovos
# regiao
# Brasil            2987280026      2.844811e+09
# Centro-Oeste       677302050      0.000000e+00
# Nordeste          1188802892      0.000000e+00
# Norte              475118410      0.000000e+00
# Sudeste           2363154118      0.000000e+00
# Sul               1270182582      0.000000e+00

# %%
plt.scatter(x=contaminados_x_recuperados['Recuperadosnovos'], y=contaminados_x_recuperados['casosAcumulado']);
